# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 8218560418408766349
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 14415560704
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 4837431244383029065
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
#  xla_global_id: 416903419]

# %%
# !git clone https://ovaheb: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@github.com/ovaheb/denoising-fluorescence.git
# Out:
# Cloning into 'denoising-fluorescence'...
# remote: Enumerating objects: 204, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 204 (delta 0), reused 0 (delta 0), pack-reused 201
# Receiving objects: 100% (204/204), 41.71 MiB | 23.29 MiB/s, done.
# Resolving deltas: 100% (41/41), done.

# %%
# !git config --global user.name "ovaheb"
# !git config --global user.email "ovaheb@gmail.com"
# !git config --global user.password "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"

# %%
# %cd /content/denoising-fluorescence
# Out:
# /content/denoising-fluorescence

# %%
# !git remote -v
# Out:
# origin	https://ovaheb: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@github.com/ovaheb/denoising-fluorescence.git (fetch)
# origin	https://ovaheb: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@github.com/ovaheb/denoising-fluorescence.git (push)

# %%
#!git remote add origin https://ovaheb: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@github.com/ovaheb/noise2noise.git

# %%
#!apt-get install python3.7

# %%
#!sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.7 1

# %%
#!sudo update-alternatives --config python3
#!python3 --version

# %%
#!sudo apt install python3-pip

# %%
# !bash /content/denoising-fluorescence/denoising/download_dataset.sh
# Out:
# ...
# --2022-12-20 11:16:23--  https://docs.google.com/uc?export=download&confirm=t&id=1juaumcGn5QlFRXRQyrqfbZBhF7oX__iW
# Resolving docs.google.com (docs.google.com)... 74.125.128.139, 74.125.128.102, 74.125.128.113, ...
# Connecting to docs.google.com (docs.google.com)|74.125.128.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0c-04-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/6kp3ekcst5du6mestl23vggmu74g5pet/1671534975000/17828459380737346642/*/1juaumcGn5QlFRXRQyrqfbZBhF7oX__iW?e=download&uuid=388d918a-49d9-4091-9598-f218b40dcb0b [following]
# ...
# --2022-12-20 11:16:23--  https://doc-0c-04-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/6kp3ekcst5du6mestl23vggmu74g5pet/1671534975000/17828459380737346642/*/1juaumcGn5QlFRXRQyrqfbZBhF7oX__iW?e=download&uuid=388d918a-49d9-4091-9598-f218b40dcb0b
# ...

# %%
# !bash /content/denoising-fluorescence/denoising/download_pretrained.sh
# Out:
# --2022-12-20 11:19:11--  https://docs.google.com/uc?export=download&confirm=&id=1kHJUqb-e7BARb63741DVdpg-WqCdG3z6
# Resolving docs.google.com (docs.google.com)... 108.177.127.138, 108.177.127.100, 108.177.127.113, ...
# Connecting to docs.google.com (docs.google.com)|108.177.127.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0c-04-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/5qvju63u95bk31fu2am1v18uomm9nslf/1671535125000/17828459380737346642/*/1kHJUqb-e7BARb63741DVdpg-WqCdG3z6?e=download&uuid=ea43bf92-a2d9-41c3-a90b-1052d6ca3e68 [following]
# ...
# --2022-12-20 11:19:11--  https://doc-0c-04-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/5qvju63u95bk31fu2am1v18uomm9nslf/1671535125000/17828459380737346642/*/1kHJUqb-e7BARb63741DVdpg-WqCdG3z6?e=download&uuid=ea43bf92-a2d9-41c3-a90b-1052d6ca3e68
# ...

# %%
# !python /content/denoising-fluorescence/denoising/benchmark.py --model n2n --data-root /content/denoising-fluorescence/dataset
# Out:
# Namespace(batch_size=4, captures=50, ckpt_dir='/scratch365/yzhu10/experiments/denoising/n2n_mixed/Feb_03/unet_noise_train[1, 2, 4, 8, 16]_test[1]_four_crop_epochs400_bs4_lr0.0001/checkpoints', ckpt_freq=50, cmap='inferno', cuda=2, data_root='/afs/crc.nd.edu/user/y/yzhu10/data/denoising/dataset', debug=False, epochs=400, exp_dir='/scratch365/yzhu10/experiments/denoising', exp_name='n2n_mixed', imsize=256, in_channels=1, log_freq=1, lr=0.0001, net='unet', noise_levels_test=[1], noise_levels_train=[1, 2, 4, 8, 16], out_channels=1, plot_epochs=5, post=False, print_freq=100, run_dir='/scratch365/yzhu10/experiments/denoising/n2n_mixed/Feb_03/unet_noise_train[1, 2, 4, 8, 16]_test[1]_four_crop_epochs400_bs4_lr0.0001', seed=1, test_batch_size=2, test_group=19, transform='four_crop', wd=0.0)
# {
#     "Dataset": "test",
#     "Noise levels": [
#         1
#     ],
#     "1 Types": [
#         "TwoPhoton_BPAE_R"
#     ],
#     "Fovs": [
#         19
#     ],
#     "# samples": 50
# }
# ...

# %%
# !python /content/denoising-fluorescence/denoising/benchmark.py --model dncnn --data-root /content/denoising-fluorescence/dataset
# Out:
# Namespace(batch_size=4, captures=50, ckpt_dir='/scratch365/yzhu10/experiments/denoising/dncnn_mixed/Feb_03/dncnn_noise_train[1, 2, 4, 8, 16]_test[1]_captures50_four_crop_epochs400_bs4_lr0.0001/checkpoints', ckpt_freq=50, cmap='inferno', cuda=1, data_root='/afs/crc.nd.edu/user/y/yzhu10/data/denoising/dataset', debug=False, depth=17, epochs=400, exp_dir='/scratch365/yzhu10/experiments/denoising', exp_name='dncnn_mixed', imsize=256, in_channels=1, log_freq=1, lr=0.0001, n_layers=17, n_params=556096, net='dncnn', noise_levels_test=[1], noise_levels_train=[1, 2, 4, 8, 16], out_channels=1, plot_epochs=5, post=False, pred_dir='/scratch365/yzhu10/experiments/denoising/dncnn_mixed/Feb_03/dncnn_noise_train[1, 2, 4, 8, 16]_test[1]_captures50_four_crop_epochs400_bs4_lr0.0001/training/predictions', print_freq=100, run_dir='/scratch365/yzhu10/experiments/denoising/dncnn_mixed/Feb_03/dncnn_noise_train[1, 2, 4, 8, 16]_test[1]_captures50_four_crop_epochs400_bs4_lr0.0001', seed=1, test_batch_size=2, t
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content//datasets
# !unrar x "/content/gdrive/MyDrive/HST_full.rar"

# %%
# !python /content/denoising-fluorescence/denoising/benchmark2.py --model n2n --data-root /content/denoising-fluorescence/dataset

# %%
# !python /content/denoising-fluorescence/denoising/benchmark2.py --model dncnn --data-root /content/denoising-fluorescence/dataset

# %%
# !rm -rf /content/denoising-fluorescence/dataset

# %%
# !git add -A
# !git commit -m "Commit 1"
# !git push origin master
# Out:
# [master c452432] Commit 1
#  102 files changed, 594 insertions(+), 3 deletions(-)
#  create mode 100644 denoising/benchmark2.py
#  create mode 100644 experiments/pretrained/.DS_Store
#  create mode 100644 experiments/pretrained/._.DS_Store
#  create mode 100644 experiments/pretrained/dncnn/.DS_Store
#  create mode 100644 experiments/pretrained/dncnn/._.DS_Store
#  create mode 100644 experiments/pretrained/dncnn/._args.txt
#  create mode 100644 experiments/pretrained/dncnn/args.txt
#  create mode 100644 experiments/pretrained/dncnn/benchmark_gpu/noise16_TwoPhoton_BPAE_B/denoising0.png
#  create mode 100644 experiments/pretrained/dncnn/benchmark_gpu/noise16_TwoPhoton_BPAE_B/denoising1.png
#  create mode 100644 experiments/pretrained/dncnn/benchmark_gpu/noise16_TwoPhoton_BPAE_G/denoising0.png
#  create mode 100644 experiments/pretrained/dncnn/benchmark_gpu/noise16_TwoPhoton_BPAE_G/denoising1.png
# ...
